# %%
#pip install stylecloud

# %%
import stylecloud as sc

# %%
#pip install pillow==9.5.0

# %%
sc.gen_stylecloud(file_path="/content/challenge.txt", output_name="ch.png")

# %%
from IPython.display import Image
Image("ch.png")

# %%
sc.gen_stylecloud(file_path="/content/challenge.txt", icon_name='fas fa-car', output_name="ch2.png")

# %%
Image("ch2.png")

# %%
sc.gen_stylecloud(file_path="/content/challenge.txt", icon_name='fas fa-star-and-crescent', output_name="ch3.png")

# %%
Image("ch3.png")

# %%
sc.gen_stylecloud(file_path="/content/challenge.txt", icon_name='fas fa-fighter-jet', output_name="ch4.png")

# %%
Image("ch4.png")
